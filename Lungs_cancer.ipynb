# %% [raw]
# To perform a full EDA which includes the following steps:
#
# 1.Summary statistics and data distribution.
# 2.Data visualization.
# 3.Checking for missing values.
# 4.Correlation analysis.
# 5.Identifying patterns and potential indicators of lung cancer.

# %% [raw]
# 1. Summary statistics and data distribution.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv("dataset.csv")

# %%
df.head(5)
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   65        1               1        1              2
# 1      F   55        1               2        2              1
# 2      F   78        2               2        1              1
# 3      M   60        2               1        1              1
# 4      F   80        1               1        2              1
#
#    CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  COUGHING  \
# 0                2        1        2         2                  2         2
# 1                1        2        2         2                  1         1
# 2                1        2        1         2                  1         1
# 3                2        1        2         1                  1         2
# 4                1        2        1         2                  1         1
#
#    SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN LUNG_CANCER
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 3000 non-null   object
#  1   AGE                    3000 non-null   int64
#  2   SMOKING                3000 non-null   int64
#  3   YELLOW_FINGERS         3000 non-null   int64
#  4   ANXIETY                3000 non-null   int64
#  5   PEER_PRESSURE          3000 non-null   int64
#  6   CHRONIC_DISEASE        3000 non-null   int64
#  7   FATIGUE                3000 non-null   int64
#  8   ALLERGY                3000 non-null   int64
#  9   WHEEZING               3000 non-null   int64
#  10  ALCOHOL_CONSUMING      3000 non-null   int64
#  11  COUGHING               3000 non-null   int64
#  12  SHORTNESS_OF_BREATH    3000 non-null   int64
#  13  SWALLOWING_DIFFICULTY  3000 non-null   int64
#  14  CHEST_PAIN             3000 non-null   int64
# ...

# %%
df.isnull().values.any()
# Out:
# False

# %% [raw]
# The summary statistics provide an overview of the dataset. Key observations are:
#
# 1.The dataset has no missing values.
# 2.Most features are binary (1 or 2), except for AGE, which is a continuous variable.
# 3.The LUNG_CANCER column has two unique values: "YES" and "NO," with almost equal distribution.

# %%
import matplotlib.pyplot as plt
import seaborn as sns


fig, axes = plt.subplots(4, 4, figsize=(20, 20))


columns = df.columns[:-1]  # Exclude the 'LUNG_CANCER' column
for i, col in enumerate(columns):
    ax = axes[i // 4, i % 4]
    if df[col].dtype == 'int64':
        sns.histplot(df[col], bins=20, kde=True, ax=ax)
    else:
        sns.countplot(x=col, data=df, ax=ax)
    ax.set_title(col)
    ax.set_xlabel('')
    ax.set_ylabel('')


plt.tight_layout()


plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='LUNG_CANCER', data=df)
plt.title('LUNG_CANCER')
plt.xlabel('')
plt.ylabel('Count')

plt.show()

# %% [raw]
# The histograms and bar plots provide a visual understanding of the data distribution and the count of categorical features. Here are some key observations:
#
# 1.Age: The distribution is fairly uniform with a slight concentration around middle age.
# 2.Binary Features: Most of these features appear evenly distributed between their two possible values.
# 3.LUNG_CANCER: The count plot shows a near-equal distribution of lung cancer cases (YES) and non-cases (NO).

# %%
df['LUNG_CANCER'] = df['LUNG_CANCER'].map({'YES': 1, 'NO': 0})
df['GENDER'] = df['GENDER'].map({'M': 0, 'F': 1})

# %%
corr_matrix = df.corr()

# Set up the matplotlib figure
plt.figure(figsize=(16, 12))

# Draw the heatmap
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)

# Set the title
plt.title('Correlation Heatmap')

# Show the plot
plt.show()

# %% [raw]
# From the above data we can see that the distribution is fairly uniform with a slight concentration around middle age. Also we can see there is acorelation between smoking, yellow fingure with Lungs_Cancer positive cases.
